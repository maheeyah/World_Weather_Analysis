# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a1a29686f4114ad03fde7106558097b

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []
#cities [0:20]
# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    #print(city_url)
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | salalah
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | tiarei
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | cirebon
# Processing Record 8 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | yabassi
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | sur
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | juneau
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | mafinga
# Processing Record 19 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | wokha
# Processing Record 22 of Set 1 | longyearbyen
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | salinopolis
# Processing Record 33 of Set 1 | vila franca do campo
# Processing Record 34 of Set 1 | lahaina
# Processing Record 35 of Set 1 | cayenne
# Processing Record 36 of Set 1 | verkhnevilyuysk
# Processing Record 37 of Set 1 | umba
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | lovozero
# Processing Record 42 of Set 1 | vuktyl
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | saint-francois
# Processing Record 45 of Set 1 | padang
# Processing Record 46 of Set 1 | ponta do sol
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | hofn
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | margate
# Processing Record 2 of Set 2 | kharod
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | tabou
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | nishihara
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | esperance
# Processing Record 10 of Set 2 | severo-kurilsk
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | ustye
# Processing Record 14 of Set 2 | creel
# Processing Record 15 of Set 2 | nemuro
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | espeland
# Processing Record 18 of Set 2 | bridlington
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | luzhou
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | yomitan
# City not found. Skipping...
# Processing Record 23 of Set 2 | marzuq
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | acapulco
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | husavik
# Processing Record 28 of Set 2 | kavaratti
# Processing Record 29 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 2 | flin flon
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | arraial do cabo
# Processing Record 33 of Set 2 | wajima
# Processing Record 34 of Set 2 | san joaquin
# Processing Record 35 of Set 2 | rabo de peixe
# Processing Record 36 of Set 2 | podosinovets
# Processing Record 37 of Set 2 | taksimo
# Processing Record 38 of Set 2 | bambous virieux
# Processing Record 39 of Set 2 | pandamatenga
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | tsiroanomandidy
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | benghazi
# Processing Record 44 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 2 | pangody
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | kieta
# Processing Record 49 of Set 2 | lalibela
# Processing Record 50 of Set 2 | saint anthony
# Processing Record 1 of Set 3 | boa esperanca
# Processing Record 2 of Set 3 | larvik
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | tezu
# Processing Record 5 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 3 | pittsburgh
# Processing Record 7 of Set 3 | grand forks
# Processing Record 8 of Set 3 | hovd
# Processing Record 9 of Set 3 | vanderhoof
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | isla vista
# Processing Record 12 of Set 3 | bluff
# Processing Record 13 of Set 3 | agadez
# Processing Record 14 of Set 3 | quzhou
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | the pas
# Processing Record 17 of Set 3 | vao
# Processing Record 18 of Set 3 | russas
# Processing Record 19 of Set 3 | cesme
# Processing Record 20 of Set 3 | ahipara
# Processing Record 21 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 3 | aljezur
# Processing Record 26 of Set 3 | garowe
# Processing Record 27 of Set 3 | veinticinco de mayo
# Processing Record 28 of Set 3 | san quintin
# Processing Record 29 of Set 3 | necochea
# Processing Record 30 of Set 3 | bendigo
# Processing Record 31 of Set 3 | lavrentiya
# Processing Record 32 of Set 3 | eyl
# Processing Record 33 of Set 3 | banepa
# Processing Record 34 of Set 3 | mount isa
# Processing Record 35 of Set 3 | beloha
# Processing Record 36 of Set 3 | gorakhpur
# Processing Record 37 of Set 3 | tautira
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | dabrowa gornicza
# Processing Record 40 of Set 3 | hennef
# Processing Record 41 of Set 3 | cabo san lucas
# Processing Record 42 of Set 3 | traganon
# Processing Record 43 of Set 3 | palmerston
# Processing Record 44 of Set 3 | oparino
# Processing Record 45 of Set 3 | pangnirtung
# Processing Record 46 of Set 3 | dunedin
# Processing Record 47 of Set 3 | hasaki
# Processing Record 48 of Set 3 | nuuk
# Processing Record 49 of Set 3 | hervey bay
# Processing Record 50 of Set 3 | maragogi
# Processing Record 1 of Set 4 | varnavino
# Processing Record 2 of Set 4 | hambantota
# Processing Record 3 of Set 4 | san patricio
# Processing Record 4 of Set 4 | kodiak
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | udayagiri
# Processing Record 7 of Set 4 | oranjestad
# Processing Record 8 of Set 4 | qinzhou
# Processing Record 9 of Set 4 | aklavik
# Processing Record 10 of Set 4 | gizo
# Processing Record 11 of Set 4 | terrace bay
# Processing Record 12 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 4 | touros
# Processing Record 14 of Set 4 | mokhotlong
# Processing Record 15 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 4 | madzhalis
# Processing Record 17 of Set 4 | shenzhen
# Processing Record 18 of Set 4 | rantepao
# Processing Record 19 of Set 4 | tarakan
# Processing Record 20 of Set 4 | muisne
# Processing Record 21 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 4 | priiskovyy
# Processing Record 24 of Set 4 | bure
# Processing Record 25 of Set 4 | hirado
# Processing Record 26 of Set 4 | fairbanks
# Processing Record 27 of Set 4 | suntar
# Processing Record 28 of Set 4 | pombas
# Processing Record 29 of Set 4 | lagoa
# Processing Record 30 of Set 4 | parrita
# Processing Record 31 of Set 4 | kondinskoye
# Processing Record 32 of Set 4 | castro
# Processing Record 33 of Set 4 | paucartambo
# City not found. Skipping...
# Processing Record 34 of Set 4 | constitucion
# Processing Record 35 of Set 4 | tougue
# Processing Record 36 of Set 4 | torrington
# Processing Record 37 of Set 4 | zharkovskiy
# Processing Record 38 of Set 4 | tomatlan
# Processing Record 39 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | burns lake
# Processing Record 41 of Set 4 | strezhevoy
# Processing Record 42 of Set 4 | ariquemes
# Processing Record 43 of Set 4 | naze
# Processing Record 44 of Set 4 | makakilo city
# Processing Record 45 of Set 4 | sao joao da barra
# Processing Record 46 of Set 4 | jieshi
# Processing Record 47 of Set 4 | punta umbria
# Processing Record 48 of Set 4 | east london
# Processing Record 49 of Set 4 | pinega
# Processing Record 50 of Set 4 | narsaq
# Processing Record 1 of Set 5 | caluquembe
# Processing Record 2 of Set 5 | yuanping
# Processing Record 3 of Set 5 | candolim
# Processing Record 4 of Set 5 | mananjary
# Processing Record 5 of Set 5 | dwarka
# Processing Record 6 of Set 5 | alofi
# Processing Record 7 of Set 5 | rorvik
# Processing Record 8 of Set 5 | komsomolskiy
# Processing Record 9 of Set 5 | meulaboh
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | torbay
# Processing Record 12 of Set 5 | valentin gomez farias
# Processing Record 13 of Set 5 | teguldet
# Processing Record 14 of Set 5 | barrow
# Processing Record 15 of Set 5 | iwanai
# Processing Record 16 of Set 5 | jaisalmer
# Processing Record 17 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | vreed en hoop
# City not found. Skipping...
# Processing Record 20 of Set 5 | vila velha
# Processing Record 21 of Set 5 | orodara
# Processing Record 22 of Set 5 | lasa
# Processing Record 23 of Set 5 | coquimbo
# Processing Record 24 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 5 | denpasar
# Processing Record 26 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 27 of Set 5 | zavetnoye
# Processing Record 28 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 5 | shimanovsk
# Processing Record 30 of Set 5 | atar
# Processing Record 31 of Set 5 | palmer
# Processing Record 32 of Set 5 | kuhestan
# City not found. Skipping...
# Processing Record 33 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 5 | abu samrah
# Processing Record 35 of Set 5 | mecca
# Processing Record 36 of Set 5 | umm kaddadah
# Processing Record 37 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 38 of Set 5 | galveston
# Processing Record 39 of Set 5 | grand gaube
# Processing Record 40 of Set 5 | kangaatsiaq
# Processing Record 41 of Set 5 | yugorsk
# Processing Record 42 of Set 5 | buin
# Processing Record 43 of Set 5 | winnemucca
# Processing Record 44 of Set 5 | finote selam
# Processing Record 45 of Set 5 | zaranj
# Processing Record 46 of Set 5 | saint-philippe
# Processing Record 47 of Set 5 | samarai
# Processing Record 48 of Set 5 | karratha
# Processing Record 49 of Set 5 | najran
# Processing Record 50 of Set 5 | dunyapur
# Processing Record 1 of Set 6 | santa cruz del sur
# Processing Record 2 of Set 6 | winslow
# Processing Record 3 of Set 6 | belyy yar
# Processing Record 4 of Set 6 | the valley
# Processing Record 5 of Set 6 | matam
# Processing Record 6 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 6 | lazaro cardenas
# Processing Record 8 of Set 6 | bilma
# Processing Record 9 of Set 6 | kaihua
# Processing Record 10 of Set 6 | charlestown
# Processing Record 11 of Set 6 | gladstone
# Processing Record 12 of Set 6 | dauriya
# Processing Record 13 of Set 6 | codrington
# Processing Record 14 of Set 6 | changtu
# Processing Record 15 of Set 6 | port hardy
# Processing Record 16 of Set 6 | cabras
# Processing Record 17 of Set 6 | san cristobal
# Processing Record 18 of Set 6 | shingu
# Processing Record 19 of Set 6 | krasnoselkup
# Processing Record 20 of Set 6 | andarab
# City not found. Skipping...
# Processing Record 21 of Set 6 | sioux lookout
# Processing Record 22 of Set 6 | progreso
# Processing Record 23 of Set 6 | yarke pole
# Processing Record 24 of Set 6 | srivardhan
# Processing Record 25 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | corumba
# Processing Record 27 of Set 6 | mangrol
# Processing Record 28 of Set 6 | canon city
# Processing Record 29 of Set 6 | jining
# Processing Record 30 of Set 6 | tsabong
# Processing Record 31 of Set 6 | iqaluit
# Processing Record 32 of Set 6 | saldanha
# Processing Record 33 of Set 6 | jiaojiang
# Processing Record 34 of Set 6 | yaan
# Processing Record 35 of Set 6 | qaanaaq
# Processing Record 36 of Set 6 | tual
# Processing Record 37 of Set 6 | shelburne
# Processing Record 38 of Set 6 | luderitz
# Processing Record 39 of Set 6 | rio bueno
# Processing Record 40 of Set 6 | cuamba
# Processing Record 41 of Set 6 | salo
# Processing Record 42 of Set 6 | henties bay
# Processing Record 43 of Set 6 | amga
# Processing Record 44 of Set 6 | lucea
# Processing Record 45 of Set 6 | angoche
# Processing Record 46 of Set 6 | takoradi
# Processing Record 47 of Set 6 | san policarpo
# Processing Record 48 of Set 6 | srednekolymsk
# Processing Record 49 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 6 | carndonagh
# Processing Record 1 of Set 7 | kudat
# Processing Record 2 of Set 7 | comodoro rivadavia
# Processing Record 3 of Set 7 | carutapera
# Processing Record 4 of Set 7 | antofagasta
# Processing Record 5 of Set 7 | bethel
# Processing Record 6 of Set 7 | ponta delgada
# Processing Record 7 of Set 7 | iralaya
# Processing Record 8 of Set 7 | mbanza-ngungu
# Processing Record 9 of Set 7 | wilkes-barre
# Processing Record 10 of Set 7 | tuatapere
# Processing Record 11 of Set 7 | valparaiso
# Processing Record 12 of Set 7 | sechura
# Processing Record 13 of Set 7 | barra do garcas
# Processing Record 14 of Set 7 | bitburg
# Processing Record 15 of Set 7 | bindura
# Processing Record 16 of Set 7 | ucluelet
# Processing Record 17 of Set 7 | marsh harbour
# Processing Record 18 of Set 7 | cockburn town
# Processing Record 19 of Set 7 | baykit
# Processing Record 20 of Set 7 | teyateyaneng
# Processing Record 21 of Set 7 | tazovskiy
# Processing Record 22 of Set 7 | rawson
# Processing Record 23 of Set 7 | miri
# Processing Record 24 of Set 7 | te anau
# Processing Record 25 of Set 7 | acajutla
# Processing Record 26 of Set 7 | nouadhibou
# Processing Record 27 of Set 7 | keti bandar
# Processing Record 28 of Set 7 | pushkino
# Processing Record 29 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 7 | ketchenery
# City not found. Skipping...
# Processing Record 31 of Set 7 | prosvet
# Processing Record 32 of Set 7 | marystown
# Processing Record 33 of Set 7 | karasburg
# Processing Record 34 of Set 7 | paamiut
# Processing Record 35 of Set 7 | flinders
# Processing Record 36 of Set 7 | bethanien
# Processing Record 37 of Set 7 | mazagao
# Processing Record 38 of Set 7 | tsuruoka
# Processing Record 39 of Set 7 | cherskiy
# Processing Record 40 of Set 7 | pevek
# Processing Record 41 of Set 7 | vila
# Processing Record 42 of Set 7 | ornes
# Processing Record 43 of Set 7 | namatanai
# Processing Record 44 of Set 7 | polyarnyy
# Processing Record 45 of Set 7 | berlevag
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | prince albert
# Processing Record 48 of Set 7 | mayumba
# Processing Record 49 of Set 7 | ekhabi
# Processing Record 50 of Set 7 | shimoda
# Processing Record 1 of Set 8 | kurilsk
# Processing Record 2 of Set 8 | chuy
# Processing Record 3 of Set 8 | lompoc
# Processing Record 4 of Set 8 | riyadh
# Processing Record 5 of Set 8 | senneterre
# Processing Record 6 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 8 | merauke
# Processing Record 8 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 8 | papara
# Processing Record 10 of Set 8 | multai
# Processing Record 11 of Set 8 | shubarkuduk
# Processing Record 12 of Set 8 | jibuti
# Processing Record 13 of Set 8 | quelimane
# Processing Record 14 of Set 8 | kirakira
# Processing Record 15 of Set 8 | kingaroy
# Processing Record 16 of Set 8 | beringovskiy
# Processing Record 17 of Set 8 | sitka
# Processing Record 18 of Set 8 | nikolayevsk-na-amure
# Processing Record 19 of Set 8 | zyryanka
# Processing Record 20 of Set 8 | burnie
# Processing Record 21 of Set 8 | jalu
# Processing Record 22 of Set 8 | alekseyevsk
# Processing Record 23 of Set 8 | pelym
# Processing Record 24 of Set 8 | port blair
# Processing Record 25 of Set 8 | okhotsk
# Processing Record 26 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 8 | discovery bay
# Processing Record 28 of Set 8 | port lincoln
# Processing Record 29 of Set 8 | wanlaweyn
# Processing Record 30 of Set 8 | callaway
# Processing Record 31 of Set 8 | avera
# Processing Record 32 of Set 8 | duminichi
# Processing Record 33 of Set 8 | ternate
# Processing Record 34 of Set 8 | bengkulu
# Processing Record 35 of Set 8 | arlit
# Processing Record 36 of Set 8 | gorom-gorom
# Processing Record 37 of Set 8 | fayetteville
# Processing Record 38 of Set 8 | kismayo
# Processing Record 39 of Set 8 | deputatskiy
# Processing Record 40 of Set 8 | caravelas
# Processing Record 41 of Set 8 | plettenberg bay
# Processing Record 42 of Set 8 | nagato
# Processing Record 43 of Set 8 | dalvik
# Processing Record 44 of Set 8 | jinka
# Processing Record 45 of Set 8 | cidreira
# Processing Record 46 of Set 8 | trinidad
# Processing Record 47 of Set 8 | sarkand
# Processing Record 48 of Set 8 | alamo
# Processing Record 49 of Set 8 | akdepe
# Processing Record 50 of Set 8 | xam nua
# Processing Record 1 of Set 9 | talnakh
# Processing Record 2 of Set 9 | coari
# Processing Record 3 of Set 9 | nelson bay
# Processing Record 4 of Set 9 | nijar
# Processing Record 5 of Set 9 | soyo
# Processing Record 6 of Set 9 | souillac
# Processing Record 7 of Set 9 | saint george
# Processing Record 8 of Set 9 | cape coast
# Processing Record 9 of Set 9 | irtyshskiy
# Processing Record 10 of Set 9 | point pedro
# Processing Record 11 of Set 9 | airai
# Processing Record 12 of Set 9 | maldonado
# Processing Record 13 of Set 9 | namibe
# Processing Record 14 of Set 9 | baghdad
# Processing Record 15 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 16 of Set 9 | tommot
# Processing Record 17 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 9 | zhetysay
# Processing Record 19 of Set 9 | half moon bay
# Processing Record 20 of Set 9 | jacareacanga
# Processing Record 21 of Set 9 | bardiyah
# Processing Record 22 of Set 9 | clyde river
# Processing Record 23 of Set 9 | el alto
# Processing Record 24 of Set 9 | lorengau
# Processing Record 25 of Set 9 | lukulu
# Processing Record 26 of Set 9 | honghu
# Processing Record 27 of Set 9 | xiangfan
# Processing Record 28 of Set 9 | scarborough
# Processing Record 29 of Set 9 | luanda
# Processing Record 30 of Set 9 | along
# Processing Record 31 of Set 9 | zhigansk
# Processing Record 32 of Set 9 | moron
# Processing Record 33 of Set 9 | maniitsoq
# Processing Record 34 of Set 9 | maarianhamina
# Processing Record 35 of Set 9 | malangali
# Processing Record 36 of Set 9 | saint john
# Processing Record 37 of Set 9 | sao gabriel da cachoeira
# Processing Record 38 of Set 9 | oytal
# Processing Record 39 of Set 9 | itarema
# Processing Record 40 of Set 9 | xingyi
# Processing Record 41 of Set 9 | faya
# Processing Record 42 of Set 9 | kirksville
# Processing Record 43 of Set 9 | lampitak
# Processing Record 44 of Set 9 | boueni
# Processing Record 45 of Set 9 | visnes
# Processing Record 46 of Set 9 | la sarre
# Processing Record 47 of Set 9 | rock sound
# Processing Record 48 of Set 9 | prince rupert
# Processing Record 49 of Set 9 | plyussa
# Processing Record 50 of Set 9 | muzhi
# Processing Record 1 of Set 10 | dawei
# Processing Record 2 of Set 10 | aksu
# Processing Record 3 of Set 10 | port hedland
# Processing Record 4 of Set 10 | pindiga
# Processing Record 5 of Set 10 | lucapa
# Processing Record 6 of Set 10 | oktyabrskiy
# Processing Record 7 of Set 10 | auki
# Processing Record 8 of Set 10 | saint augustine
# Processing Record 9 of Set 10 | kayerkan
# Processing Record 10 of Set 10 | crixas
# Processing Record 11 of Set 10 | digby
# Processing Record 12 of Set 10 | san estanislao
# Processing Record 13 of Set 10 | gulshat
# City not found. Skipping...
# Processing Record 14 of Set 10 | kodinsk
# Processing Record 15 of Set 10 | buraydah
# Processing Record 16 of Set 10 | geaca
# Processing Record 17 of Set 10 | olafsvik
# Processing Record 18 of Set 10 | sovetskiy
# Processing Record 19 of Set 10 | filingue
# Processing Record 20 of Set 10 | taga
# Processing Record 21 of Set 10 | birao
# Processing Record 22 of Set 10 | felipe carrillo puerto
# Processing Record 23 of Set 10 | tulagi
# Processing Record 24 of Set 10 | muros
# Processing Record 25 of Set 10 | dzhebariki-khaya
# Processing Record 26 of Set 10 | praya
# Processing Record 27 of Set 10 | ryki
# Processing Record 28 of Set 10 | kamaishi
# Processing Record 29 of Set 10 | sao filipe
# Processing Record 30 of Set 10 | batya
# Processing Record 31 of Set 10 | pisco
# Processing Record 32 of Set 10 | yulara
# Processing Record 33 of Set 10 | paka
# Processing Record 34 of Set 10 | pringsewu
# Processing Record 35 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 10 | bubaque
# Processing Record 37 of Set 10 | mehndawal
# Processing Record 38 of Set 10 | ust-kan
# Processing Record 39 of Set 10 | sept-iles
# Processing Record 40 of Set 10 | zhangye
# Processing Record 41 of Set 10 | mallapuram
# Processing Record 42 of Set 10 | shizunai
# Processing Record 43 of Set 10 | collierville
# Processing Record 44 of Set 10 | brae
# Processing Record 45 of Set 10 | mengcheng
# Processing Record 46 of Set 10 | muret
# Processing Record 47 of Set 10 | christchurch
# Processing Record 48 of Set 10 | geraldton
# Processing Record 49 of Set 10 | kununurra
# Processing Record 50 of Set 10 | bilibino
# Processing Record 1 of Set 11 | dabhol
# Processing Record 2 of Set 11 | cravo norte
# Processing Record 3 of Set 11 | maxixe
# Processing Record 4 of Set 11 | portland
# Processing Record 5 of Set 11 | kokopo
# Processing Record 6 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 11 | kavieng
# Processing Record 8 of Set 11 | kobryn
# Processing Record 9 of Set 11 | thinadhoo
# Processing Record 10 of Set 11 | nome
# Processing Record 11 of Set 11 | mumias
# Processing Record 12 of Set 11 | iwaki
# Processing Record 13 of Set 11 | puerto leguizamo
# Processing Record 14 of Set 11 | bone
# Processing Record 15 of Set 11 | roald
# Processing Record 16 of Set 11 | singkang
# Processing Record 17 of Set 11 | lata
# Processing Record 18 of Set 11 | bjornevatn
# Processing Record 19 of Set 11 | los corrales de buelna
# Processing Record 20 of Set 11 | asau
# Processing Record 21 of Set 11 | katherine
# Processing Record 22 of Set 11 | solnechnyy
# Processing Record 23 of Set 11 | gwadar
# Processing Record 24 of Set 11 | luena
# Processing Record 25 of Set 11 | palu
# Processing Record 26 of Set 11 | chokurdakh
# Processing Record 27 of Set 11 | sinnamary
# Processing Record 28 of Set 11 | la maddalena
# Processing Record 29 of Set 11 | hanna
# Processing Record 30 of Set 11 | lukaya
# Processing Record 31 of Set 11 | yarim
# Processing Record 32 of Set 11 | melo
# Processing Record 33 of Set 11 | linxia
# Processing Record 34 of Set 11 | payo
# Processing Record 35 of Set 11 | bobo dioulasso
# Processing Record 36 of Set 11 | seoul
# Processing Record 37 of Set 11 | shahreza
# Processing Record 38 of Set 11 | falun
# Processing Record 39 of Set 11 | batemans bay
# Processing Record 40 of Set 11 | chicama
# Processing Record 41 of Set 11 | villa corzo
# Processing Record 42 of Set 11 | staryy nadym
# Processing Record 43 of Set 11 | siniscola
# Processing Record 44 of Set 11 | puerto escondido
# Processing Record 45 of Set 11 | tubajon
# Processing Record 46 of Set 11 | leninskoye
# Processing Record 47 of Set 11 | pecos
# Processing Record 48 of Set 11 | juuru
# Processing Record 49 of Set 11 | vanavara
# Processing Record 50 of Set 11 | yerbogachen
# Processing Record 1 of Set 12 | kahului
# Processing Record 2 of Set 12 | abha
# Processing Record 3 of Set 12 | nizhniy baskunchak
# Processing Record 4 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 12 | paragominas
# Processing Record 6 of Set 12 | chapada dos guimaraes
# Processing Record 7 of Set 12 | levski
# Processing Record 8 of Set 12 | anloga
# Processing Record 9 of Set 12 | grindavik
# Processing Record 10 of Set 12 | barroualie
# City not found. Skipping...
# Processing Record 11 of Set 12 | jinchang
# Processing Record 12 of Set 12 | santiago tuxtla
# Processing Record 13 of Set 12 | morondava
# Processing Record 14 of Set 12 | ergani
# Processing Record 15 of Set 12 | topolobampo
# Processing Record 16 of Set 12 | gagarin
# Processing Record 17 of Set 12 | marsa matruh
# Processing Record 18 of Set 12 | wewak
# Processing Record 19 of Set 12 | chenzhou
# Processing Record 20 of Set 12 | pali
# Processing Record 21 of Set 12 | anaco
# Processing Record 22 of Set 12 | isangel
# Processing Record 23 of Set 12 | darnah
# Processing Record 24 of Set 12 | westport
# Processing Record 25 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 26 of Set 12 | mount forest
# Processing Record 27 of Set 12 | ust-kuyga
# Processing Record 28 of Set 12 | amapa
# Processing Record 29 of Set 12 | boa vista
# Processing Record 30 of Set 12 | zabaykalsk
# Processing Record 31 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 12 | port macquarie
# Processing Record 33 of Set 12 | bembereke
# Processing Record 34 of Set 12 | nanortalik
# Processing Record 35 of Set 12 | broome
# Processing Record 36 of Set 12 | sudak
# Processing Record 37 of Set 12 | sisimiut
# Processing Record 38 of Set 12 | havre-saint-pierre
# Processing Record 39 of Set 12 | baneasa
# Processing Record 40 of Set 12 | vaitape
# Processing Record 41 of Set 12 | port pirie
# Processing Record 42 of Set 12 | chapais
# Processing Record 43 of Set 12 | strai
# Processing Record 44 of Set 12 | buala
# Processing Record 45 of Set 12 | korla
# Processing Record 46 of Set 12 | katsuura
# Processing Record 47 of Set 12 | zafra
# Processing Record 48 of Set 12 | juegang
# Processing Record 49 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 50 of Set 12 | panzhihua
# Processing Record 1 of Set 13 | kjollefjord
# Processing Record 2 of Set 13 | sortland
# Processing Record 3 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 13 | beauchamps
# Processing Record 5 of Set 13 | asosa
# Processing Record 6 of Set 13 | suez
# Processing Record 7 of Set 13 | roblin
# Processing Record 8 of Set 13 | grants pass
# Processing Record 9 of Set 13 | la palma
# Processing Record 10 of Set 13 | camargo
# Processing Record 11 of Set 13 | zhuhai
# Processing Record 12 of Set 13 | altamira
# Processing Record 13 of Set 13 | nantucket
# Processing Record 14 of Set 13 | moranbah
# Processing Record 15 of Set 13 | bonthe
# Processing Record 16 of Set 13 | kaitangata
# Processing Record 17 of Set 13 | naryan-mar
# Processing Record 18 of Set 13 | sambava
# Processing Record 19 of Set 13 | ballina
# Processing Record 20 of Set 13 | panalingaan
# Processing Record 21 of Set 13 | los llanos de aridane
# Processing Record 22 of Set 13 | umm lajj
# Processing Record 23 of Set 13 | sadovoye
# Processing Record 24 of Set 13 | alamogordo
# Processing Record 25 of Set 13 | glendive
# Processing Record 26 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 13 | huoqiu
# Processing Record 28 of Set 13 | abu kamal
# Processing Record 29 of Set 13 | port-cartier
# Processing Record 30 of Set 13 | biak
# Processing Record 31 of Set 13 | kathu
# Processing Record 32 of Set 13 | puerto penasco
# Processing Record 33 of Set 13 | bouar
# Processing Record 34 of Set 13 | bermeo
# Processing Record 35 of Set 13 | payakumbuh
# Processing Record 36 of Set 13 | ketchikan
# Processing Record 37 of Set 13 | kalispell
# Processing Record 38 of Set 13 | praia
# Processing Record 39 of Set 13 | wines
# Processing Record 40 of Set 13 | moreira sales
# Processing Record 41 of Set 13 | kota bahru
# Processing Record 42 of Set 13 | athabasca
# Processing Record 43 of Set 13 | barra
# Processing Record 44 of Set 13 | innisfail
# Processing Record 45 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 46 of Set 13 | coahuayana
# Processing Record 47 of Set 13 | huntsville
# Processing Record 48 of Set 13 | hami
# Processing Record 49 of Set 13 | nauta
# Processing Record 50 of Set 13 | tokur
# Processing Record 1 of Set 14 | mount gambier
# Processing Record 2 of Set 14 | kitgum
# Processing Record 3 of Set 14 | gobabis
# Processing Record 4 of Set 14 | abbeville
# Processing Record 5 of Set 14 | marawi
# Processing Record 6 of Set 14 | jutai
# Processing Record 7 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 14 | tessalit
# Processing Record 9 of Set 14 | ca mau
# Processing Record 10 of Set 14 | sharlyk
# Processing Record 11 of Set 14 | leningradskiy
# Processing Record 12 of Set 14 | swift current
# Processing Record 13 of Set 14 | amuntai
# Processing Record 14 of Set 14 | santiago del estero
# Processing Record 15 of Set 14 | goba
# Processing Record 16 of Set 14 | millinocket
# Processing Record 17 of Set 14 | wanaka
# Processing Record 18 of Set 14 | tynda
# Processing Record 19 of Set 14 | boca do acre
# Processing Record 20 of Set 14 | quatre cocos
# Processing Record 21 of Set 14 | santa isabel
# Processing Record 22 of Set 14 | el rosario
# Processing Record 23 of Set 14 | belaya gora
# Processing Record 24 of Set 14 | raga
# Processing Record 25 of Set 14 | sorland
# Processing Record 26 of Set 14 | eureka
# Processing Record 27 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 14 | san rafael
# Processing Record 29 of Set 14 | grand-santi
# Processing Record 30 of Set 14 | bako
# Processing Record 31 of Set 14 | chanderi
# Processing Record 32 of Set 14 | pekalongan
# Processing Record 33 of Set 14 | nampula
# Processing Record 34 of Set 14 | leshukonskoye
# Processing Record 35 of Set 14 | banda aceh
# Processing Record 36 of Set 14 | vrangel
# Processing Record 37 of Set 14 | vila praia de ancora
# Processing Record 38 of Set 14 | bereda
# Processing Record 39 of Set 14 | kita
# Processing Record 40 of Set 14 | yar-sale
# Processing Record 41 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 14 | mezen
# Processing Record 43 of Set 14 | mwense
# Processing Record 44 of Set 14 | hokitika
# Processing Record 45 of Set 14 | cedro
# Processing Record 46 of Set 14 | dabat
# Processing Record 47 of Set 14 | mesyagutovo
# Processing Record 48 of Set 14 | sao felix do xingu
# Processing Record 49 of Set 14 | waingapu
# Processing Record 50 of Set 14 | greenville
# Processing Record 1 of Set 15 | abalak
# Processing Record 2 of Set 15 | huanren
# Processing Record 3 of Set 15 | kayes
# Processing Record 4 of Set 15 | kamloops
# Processing Record 5 of Set 15 | albeni
# Processing Record 6 of Set 15 | acarau
# Processing Record 7 of Set 15 | ileza
# Processing Record 8 of Set 15 | tromso
# Processing Record 9 of Set 15 | verkh-usugli
# Processing Record 10 of Set 15 | sohbatpur
# Processing Record 11 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 12 of Set 15 | lokoja
# Processing Record 13 of Set 15 | primorsko-akhtarsk
# Processing Record 14 of Set 15 | ugoofaaru
# Processing Record 15 of Set 15 | poum
# Processing Record 16 of Set 15 | marathon
# Processing Record 17 of Set 15 | las cruces
# Processing Record 18 of Set 15 | cockburn harbour
# City not found. Skipping...
# Processing Record 19 of Set 15 | selishche
# Processing Record 20 of Set 15 | dzerzhinskoye
# Processing Record 21 of Set 15 | arman
# Processing Record 22 of Set 15 | xinzhi
# Processing Record 23 of Set 15 | roma
# Processing Record 24 of Set 15 | salinas
# Processing Record 25 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 26 of Set 15 | tura
# Processing Record 27 of Set 15 | entroncamento
# Processing Record 28 of Set 15 | anadyr
# Processing Record 29 of Set 15 | nizhniy bestyakh
# Processing Record 30 of Set 15 | inirida
# Processing Record 31 of Set 15 | dingle
# Processing Record 32 of Set 15 | salym
# Processing Record 33 of Set 15 | mahibadhoo
# Processing Record 34 of Set 15 | asfi
# Processing Record 35 of Set 15 | ilorin
# Processing Record 36 of Set 15 | kapit
# Processing Record 37 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 38 of Set 15 | kulachi
# Processing Record 39 of Set 15 | porto belo
# Processing Record 40 of Set 15 | kouroussa
# Processing Record 41 of Set 15 | goundi
# Processing Record 42 of Set 15 | zhigalovo
# Processing Record 43 of Set 15 | russell
# Processing Record 44 of Set 15 | rodrigues alves
# Processing Record 45 of Set 15 | balikpapan
# Processing Record 46 of Set 15 | yangambi
# Processing Record 47 of Set 15 | hemsedal
# Processing Record 48 of Set 15 | sakakah
# Processing Record 49 of Set 15 | lithgow
# Processing Record 50 of Set 15 | college
# Processing Record 1 of Set 16 | yabrud
# Processing Record 2 of Set 16 | kitimat
# Processing Record 3 of Set 16 | kysyl-syr
# Processing Record 4 of Set 16 | kungalv
# Processing Record 5 of Set 16 | taltal
# Processing Record 6 of Set 16 | damaturu
# Processing Record 7 of Set 16 | port-gentil
# Processing Record 8 of Set 16 | florianopolis
# Processing Record 9 of Set 16 | abu dhabi
# Processing Record 10 of Set 16 | termini imerese
# Processing Record 11 of Set 16 | harwich
# Processing Record 12 of Set 16 | boma
# Processing Record 13 of Set 16 | manado
# Processing Record 14 of Set 16 | marsabit
# Processing Record 15 of Set 16 | dulyapino
# Processing Record 16 of Set 16 | shangzhi
# Processing Record 17 of Set 16 | asuncion
# Processing Record 18 of Set 16 | vestmannaeyjar
# Processing Record 19 of Set 16 | kirkwall
# Processing Record 20 of Set 16 | beira
# Processing Record 21 of Set 16 | znamenskoye
# Processing Record 22 of Set 16 | severodvinsk
# Processing Record 23 of Set 16 | massaguet
# Processing Record 24 of Set 16 | algeciras
# Processing Record 25 of Set 16 | anaconda
# Processing Record 26 of Set 16 | tarpon springs
# Processing Record 27 of Set 16 | am timan
# Processing Record 28 of Set 16 | luau
# Processing Record 29 of Set 16 | pozo colorado
# Processing Record 30 of Set 16 | daru
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 725

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas -53.1500  -70.9167     60.91        55          75
# 1        Atuona  -9.8000 -139.0333     78.53        77          24
# 2       Salalah  17.0151   54.0924     68.23        77          91
# 3        Hobart -42.8794  147.3294     65.26        88          75
# 4        Tiarei -17.5333 -149.3333     87.82        76          11
# 5   Provideniya  64.3833 -173.3000     -7.49        71           0
# 6       Cirebon  -6.7063  108.5570     78.91        81         100
# 7     Busselton -33.6500  115.3333     62.20        49          34
# 8       Ushuaia -54.8000  -68.3000     53.44        75         100
# 9       Yabassi   4.4570    9.9682     75.92        89          91
#
#    Wind Speed Country          Current Description
# 0       23.02      CL  light intensity shower rain
# 1       18.41      PF                   light rain
# 2        2.82      OM              overcast clouds
# 3       10.36      AU                broken clouds
# 4       11.52      PF                   few clouds
# 5       17.90      RU                    clear sky
# 6        2.53      ID                moderate rain
# 7       15.68      AU             scattered clouds
# 8        7.83      AR              overcast clouds
# 9        0.29      CM              overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

#Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

#Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Punta Arenas      CL -53.1500  -70.9167     60.91        55          75
# 1        Atuona      PF  -9.8000 -139.0333     78.53        77          24
# 2       Salalah      OM  17.0151   54.0924     68.23        77          91
# 3        Hobart      AU -42.8794  147.3294     65.26        88          75
# 4        Tiarei      PF -17.5333 -149.3333     87.82        76          11
# 5   Provideniya      RU  64.3833 -173.3000     -7.49        71           0
# 6       Cirebon      ID  -6.7063  108.5570     78.91        81         100
# 7     Busselton      AU -33.6500  115.3333     62.20        49          34
# 8       Ushuaia      AR -54.8000  -68.3000     53.44        75         100
# 9       Yabassi      CM   4.4570    9.9682     75.92        89          91
#
#    Wind Speed          Current Description
# 0       23.02  light intensity shower rain
# 1       18.41                   light rain
# 2        2.82              overcast clouds
# 3       10.36                broken clouds
# 4       11.52                   few clouds
# 5       17.90                    clear sky
# 6        2.53                moderate rain
# 7       15.68             scattered clouds
# 8        7.83              overcast clouds
# 9        0.29              overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
